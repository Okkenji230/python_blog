# %% [markdown]
# # ECサイトなどのカタログデータの処理・分析の小技集

# %% [markdown]
# 一部のECサイトでは、販売商品のカタログデータをAPIにより取得することができます。このようなデータには、商品名、商品の補足説明、価格などの情報が含まれています。ここでは、このようなECサイトのカタログデータを処理・分析するためのpythonの小技をまとめました。ここで用いるデータは「楽天ブックス書籍検索API」を利用してダウンロードした書籍情報データです。

# %%
# japanize_matplotlibが未インストール状態の場合に、コメント解除して本セルを単独で実行する（先頭に!が必要）
#!pip install japanize-matplotlib

# %%
# Googleドライブをマウントする場合、２行のコメント解除して本セルを単独で実行する
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# ライブラリのインポート
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font=['IPAexGothic'])
import japanize_matplotlib # matplotlib日本語
from google.colab import files # 画像ファイルダウンロード用

# %% [markdown]
# parquetファイルからデータフレームに読み込む

# %%
df01 = pd.read_parquet('/content/drive/My Drive/Colab Notebooks/rakuten_books.parquet')
df01.iloc[1000:1003,:]
# Out:
#                                title  ... reviewAverage
# 1000                魔法科高校の劣等生　古都内乱編2  ...           5.0
# 1001                            文豪春秋  ...           0.0
# 1002  SNOOPY マルチに使えるBIGピクニックバッグ BOOK  ...           4.1
#
# [3 rows x 30 columns]

# %%
# データフレームの情報を表示する
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3000 non-null   object
#  1   titleKana       3000 non-null   object
#  2   subTitle        3000 non-null   object
#  3   subTitleKana    3000 non-null   object
#  4   seriesName      3000 non-null   object
#  5   seriesNameKana  3000 non-null   object
#  6   contents        3000 non-null   object
#  7   author          3000 non-null   object
#  8   authorKana      3000 non-null   object
#  9   publisherName   3000 non-null   object
#  10  size            3000 non-null   object
#  11  isbn            3000 non-null   object
#  12  itemCaption     3000 non-null   object
#  13  salesDate       3000 non-null   object
#  14  itemPrice       3000 non-null   int64
#  15  listPrice       3000 non-null   int64
#  16  discountRate    3000 non-null   int64
#  17  discountPrice   3000 non-null   int64
#  18  itemUrl         3000 non-null   object
#  19  affiliateUrl    3000 non-null   object
#  20  smallImageUrl   3000 non-null   object
#  21  mediumImageUrl  3000 non-null   object
#  22  largeImageUrl   3000 non-null   object
#  23  chirayomiUrl    3000 non-null   object
#  24  availability    3000 non-null   object
#  25  postageFlag     3000 non-null   int64
#  26  limitedFlag     3000 non-null   int64
#  27  reviewCount     3000 non-null   int64
#  28  booksGenreId    3000 non-null   object
#  29  reviewAverage   3000 non-null   float64
# dtypes: float64(1), int64(7), object(22)
# memory usage: 703.2+ KB

# %%
# 列を絞り込む
focus_cols=['title','subTitle','seriesName','contents','author','publisherName','size','itemCaption','salesDate','itemPrice','reviewCount','reviewAverage']
df1 = df01.loc[:,focus_cols]

# %% [markdown]
# **テキスト項目の文字列検索**

# %% [markdown]
# まず、テキスト情報からあるキーワードを含む行を抽出するケースを考えます。pandasのSeries.str.contains()を用います。これにより、指定した文字列を含む行のみを取り出すことができます。

# %%
# テキスト項目で特定の文字列を検索する
col_name = 'title'
ch_kw = '資産'
df201 = df1[df1[col_name].str.contains(ch_kw)]
print('該当するデータ件数 = ',len(df201))
df201.head(2)
# Out:
# 該当するデータ件数 =  3
#                                                   title  ... reviewAverage
# 582   2020-2021年版　みんなが欲しかった！　FPの教科書1級　Vol．1　ライフプランニン...  ...          0.00
# 2444                                 山崎元の“やってはいけない”資産運用  ...          4.33
#
# [2 rows x 12 columns]

# %% [markdown]
# 次に、２つのキーワードについて、その両方を含む行を取り出したい（and条件）場合は、一つのキーワードで絞りこんだデータフレームに対してもう一つのキーワードでさらに絞りこみをかけることでできます。

# %%
# テキスト項目で特定の複数の文字列をand検索する
col_name = 'itemCaption'
ch_kw1 = '成功'; ch_kw2 = '金'
df202 = df1[df1[col_name].str.contains(ch_kw1)]
df203 = df202[df202[col_name].str.contains(ch_kw2)]
print('該当するデータ件数 = ',len(df203))
df203.head(2)
# Out:
# 該当するデータ件数 =  1
#            title subTitle seriesName  ... itemPrice reviewCount reviewAverage
# 1746  進化する里山資本主義                      ...      1980           1           5.0
#
# [1 rows x 12 columns]

# %% [markdown]
# 一方、２つのキーワードのどちらかが含まれる行を抽出したい（or条件）場合は、元のデータフレームを個別のキーワードで絞りこんだ結果を縦結合することでできます。これは検索対象の列が異なる場合にも応用できます。どちらかの検索結果がゼロ行でも特に問題はありません。

# %%
# テキスト項目で特定の複数の文字列をor検索する
col_name = 'title'
ch_kw1 = '資産'; ch_kw2 = '財産'
df204 = df1[df1[col_name].str.contains(ch_kw1)]
df205 = df1[df1[col_name].str.contains(ch_kw2)]
df206 = pd.concat([df204,df205])
print('該当するデータ件数 = ',len(df206))
df206.head(2)
# Out:
# 該当するデータ件数 =  6
#                                                   title  ... reviewAverage
# 582   2020-2021年版　みんなが欲しかった！　FPの教科書1級　Vol．1　ライフプランニン...  ...          0.00
# 2444                                 山崎元の“やってはいけない”資産運用  ...          4.33
#
# [2 rows x 12 columns]

# %% [markdown]
# **特定の数値項目で条件検索する**

# %% [markdown]
# 今度は数値データが入った列について、ある条件を満たす行を取り出すことを考えます。例えば値がゼロより大きい行を抽出するには、df[df['列名']>0]とする書き方と、df.query('列名>0')という書き方があります。

# %%
# 数値変数で条件検索する
ch_col='reviewCount'; s_val=500
df31 = df1[df1[ch_col] >= s_val]
#別の記述法
#df31 = df1.query('{0} >= @s_val'.format(ch_col))
print('該当するケース数: ',len(df31))
df31.head(3)
# Out:
# 該当するケース数:  3
#                       title  ... reviewAverage
# 424   FACTFULNESS（ファクトフルネス）  ...          4.40
# 458   ぼくはイエローでホワイトで、ちょっとブルー  ...          4.49
# 1653                  メモの魔力  ...          4.14
#
# [3 rows x 12 columns]

# %%
#数値検索の別の記述法
ch_col='reviewAverage'; s_val=5
df32 = df1.query('{0} >= @s_val'.format(ch_col))
print('該当するケース数: ',len(df32))
df32.head(2)
# Out:
# 該当するケース数:  360
#                                  title  ... reviewAverage
# 3                    YUZU’LL　BE　BACK　2  ...           5.0
# 12  cookpadLive公式レシピ 和牛キッチン 川西シェフ・助手水田  ...           5.0
#
# [2 rows x 12 columns]

# %% [markdown]
# **特定の列項目が空でないケースを抽出する**

# %% [markdown]
# 次に、テキストからなる特定の列項目が空でないケースを抽出する方法を考えます。テキスト情報で何も書かれていないのは空文字列('')なので、まず空文字列を欠損値(NaN)に置き換えます。その後で欠損値を含む行を削除します。

# %%
# 列名を指定する
col_name = 'contents'
# データフレームをコピーする
df211 = df1.copy()
#空白をまずNaNに置き換え
df211[col_name].replace('', np.nan, inplace=True)
#Nanを削除 inplace=Trueでdfが上書きされる。
df211.dropna(subset=[col_name], inplace=True)
print('該当するデータ件数 = ',len(df211))
df211.head(2)
# Out:
# 該当するデータ件数 =  36
#                            title  ... reviewAverage
# 39     BARFOUT！（vol．298（JULY　20）  ...           5.0
# 126  COTTON　FRIEND　SEWING（vol．4）  ...           0.0
#
# [2 rows x 12 columns]

# %% [markdown]
# **定型テキストの出現頻度を求める**

# %% [markdown]
# テキスト情報の列の中でも、出現する文字列のパターンが限定されている場合があります。いわゆる「カテゴリカルデータ」に相当するものです。その出現頻度を知りたいことはよくあります。これにはcollectionsライブラリのCounter()メソッドを用います。

# %%
# 列名を指定する
import pprint
col_name = 'publisherName'
import collections
c_count = collections.Counter(df1[col_name])
pprint.pprint(c_count, compact=True)
# Out:
# Counter({'講談社': 265,
#          'KADOKAWA': 246,
#          '集英社': 187,
#          '小学館': 161,
#          '宝島社': 81,
#          'スクウェア・エニックス': 69,
#          '白泉社': 46,
#          '秋田書店': 44,
#          '幻冬舎': 37,
#          '朝日新聞出版': 36,
#          '双葉社': 36,
#          '新潮社': 36,
#          'ダイヤモンド社': 35,
#          'アルファポリス': 35,
#          'TAC出版': 32,
#          '文藝春秋': 31,
#          'ワニブックス': 29,
#          '扶桑社': 29,
#          '一迅社': 29,
#          '光文社': 29,
#          '日経BP': 28,
#          '学研プラス': 25,
#          '旺文社': 25,
#          'SBクリエイティブ': 23,
#          '中央公論新社': 21,
#          '主婦の友社': 20,
#          '祥伝社': 19,
#          '徳間書店': 18,
#          'メディック\u3000メディア': 17,
#          '技術評論社': 17,
#          'NHK出版': 17,
#          'サンマーク出版': 16,
#          'マガジンハウス': 15,
#          '医学書院': 15,
#          '中央法規出版': 15,
#          '芳文社': 15,
#          '中央経済社': 15,
#          'コアミックス': 14,
#          'ぴあ': 14,
#          '河出書房新社': 14,
#          '東洋経済新報社': 13,
#          '岩波書店': 13,
#          '早川書房': 12,
#          '医学通信社': 12,
#          '日経BP 日本経済新聞出版本部': 11,
#          'ポプラ社': 11,
#          'KADOKAWA\u3000Game\u3000Linkage': 10,
#          'じほう': 10,
#          'リブレ': 10,
#          '医歯薬出版': 10,
#          '日本文芸社': 10,
#          '晋遊舎': 10,
#          '東京ニュース通信社': 9,
#          '文響社': 9,
#          '星海社': 9,
#          '筑摩書房': 9,
#          'マッグガーデン': 9,
#          'コスミック出版': 9,
#          '教学社': 9,
#          'ベネッセコーポレーション': 8,
#          'マキノ出版': 8,
#          '日本医歯薬研修協会': 8,
#          '日本能率協会マネジメントセンター': 8,
#          '三省堂': 8,
#          '誠文堂新光社': 7,
#          '日本ヴォーグ社': 7,
#          'ぶんか社': 7,
#          '主婦と生活社': 7,
#          '昭文社': 7,
#          '新書館': 7,
#          'ビジネス社': 7,
#          '宙出版': 7,
#          '数研出版': 7,
#          '実務教育出版': 7,
#          'ブティック社': 6,
#          'TOブックス': 6,
#          '大和書房': 6,
#          '竹書房': 6,
#          'かんき出版': 6,
#          '実業之日本社': 6,
#          '晶文社': 6,
#          'マイナビ出版': 6,
#          'イカロス出版': 6,
#          'ホビージャパン': 6,
#          'ニュートンプレス': 6,
#          'ナツメ社': 6,
#          '角川春樹事務所': 6,
#          '日本経済新聞出版社': 6,
#          'プランタン出版': 6,
#          'PHP研究所': 5,
#          'リイド社': 5,
#          '飛鳥新社': 5,
#          '玄光社': 5,
#          'グラフィック社': 5,
#          'ベースボール・マガジン社': 5,
#          '三栄': 5,
#          'リットーミュージック': 5,
#          'ぱる出版': 5,
#          '秀和システム': 5,
#          '幸福の科学出版': 5,
#          '羊土社': 5,
#          '株式会社シンコーミュージック': 5,
#          'ツールボックス': 5,
#          'すばる舎': 5,
#          'フロンティアワークス': 5,
#          '山と溪谷社': 5,
#          'スターツ出版': 5,
#          'メディカル・サイエンス・インターナショナル': 5,
#          '声の教育社': 5,
#          '翔泳社': 5,
#          '少年画報社': 4,
#          '幻冬舎コミックス': 4,
#          'ソーテック社': 4,
#          'JTBパブリッシング': 4,
#          'ユーキャン学び出版／自由国民社': 4,
#          '金原出版': 4,
#          '第一出版（千代田区）': 4,
#          '柴田書店': 4,
#          'オーム社': 4,
#          '照林社': 4,
#          '東京創元社': 4,
#          '世界文化社': 4,
#          'プレジデント社': 4,
#          '文光堂': 4,
#          '文化学園\u3000文化出版局': 4,
#          '建築資料研究社': 4,
#          'オーバーラップ': 4,
#          'ヒーローズ': 4,
#          'リトルモア': 4,
#          '交通新聞社': 4,
#          '東京リーガルマインド': 4,
#          'ハーパーコリンズ・ジャパン': 4,
#          '宅建学院': 4,
#          '金剛出版': 4,
#          '富士通エフ・オー・エム': 3,
#          'インプレス': 3,
#          '株式会社音楽之友社': 3,
#          '三笠書房': 3,
#          '南江堂': 3,
#          '明日香出版社': 3,
#          '高橋書店': 3,
#          'シンコーミュージック・エンタテイメント': 3,
#          '代々木ライブラリー': 3,
#          '日本図書センター': 3,
#          'DU BOOKS': 3,
#          '克誠堂出版': 3,
#          'ステレオサウンド': 3,
#          'つり人社': 3,
#          'ハート出版': 3,
#          'アスコム': 3,
#          '日本実業出版社': 3,
#          '税務研究会出版局': 3,
#          'ホーム社': 3,
#          '日本評論社': 3,
#          '大都社': 3,
#          '（株）主婦の友社': 3,
#          '中外医学社': 3,
#          'サンクチュアリ出版': 3,
#          '西東社': 3,
#          'きんざい': 3,
#          'さくら舎': 3,
#          'ブライト出版': 3,
#          '左右社': 3,
#          '辰巳出版': 3,
#          '内外出版社': 3,
#          '笠倉出版社': 3,
#          '英治出版': 3,
#          '産業環境管理協会': 3,
#          'メジカルビュー社': 3,
#          '有斐閣': 3,
#          '鹿砦社': 3,
#          'カンゼン': 3,
#          '文理': 3,
#          '原書房': 3,
#          '公共建築協会': 3,
#          '同友館': 3,
#          '学陽書房': 3,
#          'マイクロマガジン社': 3,
#          'WAVE出版': 3,
#          'アチーブメント出版': 3,
#          'エクスナレッジ': 3,
#          'ミシマ社': 3,
#          '教育開発研究所': 3,
#          '金融財政事情研究会': 3,
#          '東京大学出版会': 3,
#          '光村教育図書': 3,
#          '毎日新聞出版': 3,
#          '日経BP\u3000日本経済新聞出版本部': 3,
#          '静山社': 3,
#          '本の雑誌社': 3,
#          'メディカ出版': 3,
#          '日本漢字能力検定協会': 3,
#          'ナチュラルスピリット': 3,
#          'ブラウンズブックス': 2,
#          '全日出版社': 2,
#          '運動と医学の出版社': 2,
#          'パイ インターナショナル': 2,
#          '日本看護協会出版会': 2,
#          '産経新聞出版': 2,
#          '山と渓谷社': 2,
#          '総合法令出版': 2,
#          '学芸出版社': 2,
#          'HANA': 2,
#          'クインテッセンス出版': 2,
#          'へるす出版': 2,
#          '誠信書房': 2,
#          'スイッチ・パブリッシング': 2,
#          '学研メディカル秀潤社': 2,
#          '交通タイムス社': 2,
#          '啓明書房': 2,
#          'TAC': 2,
#          'コントロール社': 2,
#          'ネコ・パブリッシング': 2,
#          '矢野恒太記念会': 2,
#          '方丈社': 2,
#          '弘文社': 2,
#          'ニューズピックス': 2,
#          'シーニュ': 2,
#          '三才ブックス': 2,
#          'CCCメディアハウス': 2,
#          '明治図書出版': 2,
#          '早稲田経営出版': 2,
#          '新日本法規出版': 2,
#          'ニコリ': 2,
#          '新紀元社': 2,
#          'ワック': 2,
#          '英和出版社': 2,
#          '青幻舎': 2,
#          'ゴルフダイジェスト社': 2,
#          '廣済堂出版': 2,
#          '三交社': 2,
#          'アース・スターエンターテイメント': 2,
#          'LINE\u3000Digital\u3000Frontier': 2,
#          '家の光協会': 2,
#          'イースト・プレス': 2,
#          '（株）ポプラ社': 2,
#          '成美堂出版': 2,
#          'かや書房': 2,
#          '薬事日報社': 2,
#          '集英社クリエイティブ': 2,
#          '聖教新聞社': 2,
#          'ライツ社': 2,
#          'フレックスコミックス': 2,
#          'フィルムアート社': 2,
#          '女子栄養大学出版部': 2,
#          '発明推進協会': 2,
#          '平凡社': 2,
#          'アチーブメント': 2,
#          'エンスカイ': 2,
#          '集英社インターナショナル': 2,
#          '日本加除出版': 2,
#          'メディアソフト': 2,
#          'ジャパンタイムズ出版': 2,
#          '南山堂': 2,
#          '講談社ビーシー': 2,
#          'リックテレコム': 2,
#          '花伝社': 2,
#          '山川出版社': 2,
#          '地域開発研究所（文京区）': 2,
#          '青春出版社': 2,
#          '株式会社アルク': 2,
#          'ハースト婦人画報社': 2,
#          'ディスカヴァー・トゥエンティワン': 2,
#          '（株）永岡書店': 2,
#          '日経HR': 2,
#          '春秋社': 2,
#          '彗星社': 2,
#          '金芳堂': 2,
#          'みすず書房': 2,
#          'モバイルメディアリサーチ': 2,
#          'クロスメディア・パブリッシング': 2,
#          '増進堂・受験研究社': 2,
#          'スポーツニッポン新聞社': 1,
#          'アンビット': 1,
#          'ヨシモトブックス': 1,
#          '舵社': 1,
#          '中日新聞東京本社': 1,
#          '柏書房': 1,
#          'メディア・ボーイ': 1,
#          'ほぼ日': 1,
#          '東洋館出版社': 1,
#          '彩流社': 1,
#          '国際ビジネスコミュニケーション協会': 1,
#          'ヤマハミュージックエンタテインメントホールディングス': 1,
#          'オライリー・ジャパン': 1,
#          '第一法規': 1,
#          'スタンダーズ': 1,
#          '青灯社': 1,
#          '芸術新聞社': 1,
#          '大日本絵画': 1,
#          'かも出版': 1,
#          'NEUTRAL COLORS': 1,
#          'フレーベル館': 1,
#          '◯エトランジェディコスタリカ': 1,
#          '日本医事新報社': 1,
#          'エイアンドエフ': 1,
#          '風雲舎': 1,
#          '辰已法律研究所': 1,
#          '白水社': 1,
#          'ヤマハミュージックメディア': 1,
#          '風土社（千代田区）': 1,
#          '三修社': 1,
#          '信山社出版': 1,
#          '大月書店': 1,
#          '株式会社リンケージ': 1,
#          '民事法研究会': 1,
#          '京都大学学術出版会': 1,
#          '凡人社': 1,
#          'アガルート・パブリッシング': 1,
#          '合同出版': 1,
#          '太田出版': 1,
#          '笠間書院': 1,
#          'インプレスR&D': 1,
#          'マイルスタッフ': 1,
#          '道玄坂書房': 1,
#          '一二三書房': 1,
#          '世界思想社': 1,
#          '新評論': 1,
#          '日本糖尿病療養指導士認定機構': 1,
#          '朝日出版社': 1,
#          '西日本新聞社': 1,
#          '自由工房': 1,
#          '農山漁村文化協会': 1,
#          'ユサブル': 1,
#          '青弓社': 1,
#          'あさ出版': 1,
#          '新星出版社': 1,
#          'FCEパブリッシング（キングベアー出版）': 1,
#          '株式会社法研': 1,
#          '法政大学出版局': 1,
#          '第三書館': 1,
#          '偕成社': 1,
#          '化学同人': 1,
#          '駿台文庫': 1,
#          'テコム出版事業部': 1,
#          'gene': 1,
#          '美術出版社': 1,
#          '診断と治療社': 1,
#          'ガイドワークス': 1,
#          'ロングランドジェイ': 1,
#          'カエルム': 1,
#          'エネルギーフォーラム': 1,
#          '三輪書店': 1,
#          '自由国民社': 1,
#          '母子衛生研究会': 1,
#          'マール社': 1,
#          'アイハーツ': 1,
#          'ソシム': 1,
#          '弘文堂': 1,
#          '幻戯書房': 1,
#          '（株）リベラル社': 1,
#          'スタディカンパニー': 1,
#          '創元社': 1,
#          '大洋図書': 1,
#          '（株）東京書店': 1,
#          '並木書房': 1,
#          '全日本病院出版会': 1,
#          '日本関税協会': 1,
#          'いろは出版': 1,
#          'さくら社': 1,
#          '草思社': 1,
#          '皓星社': 1,
#          '総合医学社': 1,
#          '公論出版': 1,
#          'アトランテ': 1,
#          'メディアプラス': 1,
#          'ネコノス': 1,
#          'オレンジページ': 1,
#          'ヒョーロン・パブリッシャーズ': 1,
#          '緑風出版': 1,
#          '第三文明社': 1,
#          'Book&Design': 1,
#          '薬ゼミ情報教育センター': 1,
#          'ホットリバー': 1,
#          '有信堂高文社': 1,
#          '八重洲出版': 1,
#          '（株）光文社': 1,
#          'ドレミ楽譜出版社': 1,
#          'A-Works': 1,
#          'ヴィレッジブックス': 1,
#          'くもん出版': 1,
#          '百万年書房': 1,
#          '日東書院本社': 1,
#          '青林堂': 1,
#          'スタンド・ブックス': 1,
#          'グループSNE': 1,
#          'セルバ出版': 1,
#          'フローラル出版': 1,
#          'クリニコ出版': 1,
#          '日本公認会計士協会': 1,
#          '東京図書': 1,
#          'あすなろ書房': 1,
#          '商事法務': 1,
#          '角川アスキー総合研究所': 1,
#          '風媒社': 1,
#          'クラーケン': 1,
#          '経済調査会': 1,
#          '丸善出版': 1,
#          'ソル・メディア': 1,
#          '光村推古書院': 1,
#          '婦人之友社': 1,
#          'つた書房': 1,
#          '潮出版社': 1,
#          '浅川書房': 1,
#          'ナガセ': 1,
#          '日本水道新聞社': 1,
#          '文林堂': 1,
#          '展望社（文京区）': 1,
#          'テレビ朝日': 1,
#          '青志社': 1,
#          '彩文館出版': 1,
#          '労務行政': 1,
#          '（株）彗星社': 1,
#          '新興医学出版社': 1,
#          '赤ちゃんとママ社': 1,
#          'コアマガジン': 1,
#          'Jパブリッシング': 1,
#          '心交社': 1,
#          '': 1,
#          '勉誠出版': 1,
#          '彩図社': 1,
#          '体育とスポーツ出版社': 1,
#          'パズルメイト': 1,
#          '三宝出版': 1,
#          '少年写真新聞社': 1,
#          'フォト・パブリッシング': 1,
#          '慶應義塾大学出版会': 1,
#          '金星堂': 1,
#          '玄文社（東京）': 1,
#          '静岡新聞社': 1,
#          'わかさ出版': 1,
#          '青土社': 1,
#          'チャイルド本社': 1,
#          '京阪神エルマガジン社': 1,
#          '総合資格': 1,
#          'ブロンズ新社': 1,
#          '学術図書出版社': 1,
#          '東京化学同人': 1,
#          '（株）みらいパブリッシング': 1,
#          'ロフトブックス': 1,
#          '建設電気技術者協会': 1,
#          'コモンズ': 1,
#          '学事出版': 1,
#          '評論社': 1,
#          'パンローリング': 1,
#          '○レイメイ藤井': 1,
#          'キルタイムコミュニケーション': 1,
#          'SDP': 1,
#          'ネクストF': 1,
#          '西村書店': 1,
#          'JMA・アソシエイツステップワークス事業': 1,
#          'プレビジョン': 1,
#          '日本離島センター': 1,
#          '海竜社': 1,
#          'ヒカルランド': 1,
#          'BABジャパン': 1,
#          '宣伝会議': 1,
#          'リクルート': 1,
#          'ワニ・プラス': 1,
#          'ビー・エヌ・エヌ新社': 1,
#          '東京法令出版': 1,
#          'ロングランドジェイ有限会社': 1,
#          '東京医学社': 1,
#          '理論社': 1,
#          '小学館集英社プロダクション': 1,
#          '教英出版': 1,
#          '永岡書店': 1,
#          '888ブックス': 1,
#          '今日の話題社': 1,
#          'NORTH VILLAGE': 1,
#          '一ツ橋書店': 1,
#          'standards': 1,
#          '（株）地球丸': 1,
#          'エムディエヌコーポレーション': 1,
#          '二見書房': 1,
#          '森北出版': 1,
#          'フォレスト出版': 1,
#          '毎日ワンズ': 1,
#          '文一総合出版': 1,
#          '税務経理協会': 1,
#          '吉川弘文館': 1,
#          'スタジオタッククリエイティブ': 1,
#          'アスク出版': 1,
#          '英俊社': 1,
#          'アルファベータブックス': 1})

# %%
# カウント上位のリストを得る
p_names, p_counts = zip(*c_count.most_common(10))
print(p_names)
# Out:
# ('講談社', 'KADOKAWA', '集英社', '小学館', '宝島社', 'スクウェア・エニックス', '白泉社', '秋田書店', '幻冬舎', '朝日新聞出版')

# %% [markdown]
# **正規表現による検索**

# %% [markdown]
# 決まった文字列ではなく、ある規則性を持った文字列を検索したい場合には「正規表現」による検索を用います。ここでは、コミックセットのように複数の書籍が一括して販売されているケースを検索し、「○冊セット」の○にあたる数字を取り出すことを考えます。ここではpythonライブラリ're'のsearchメソッドを一件につき2回用いています。１回目の適用で'○冊セット'の文字列をとりだし、２回目の適用でその中の○にあたる数字の部分を取り出して、int()で数値化しています。

# %%
def func_bulk(s):
    """タイトル文字列sの中の冊数を表すパターンを検索して冊数の数値を返す"""
    nitem = 0
    blkstr1 = re.search('[0-9]+巻セット',s)
    if not blkstr1 is None:
        nitem = int(re.search('[0-9]+',blkstr1.group()).group())
        return nitem
    blkstr2 = re.search('[0-9]+冊セット',s)
    if not blkstr2 is None:
        nitem = int(re.search('[0-9]+',blkstr2.group()).group())
        return nitem
    blkstr3 = re.search('全[0-9]+巻',s)
    if not blkstr3 is None:
        nitem = int(re.search('[0-9]+',blkstr3.group()).group())
        return nitem
    blkstr4 = re.search('全[0-9]+冊',s)
    if not blkstr4 is None:
        nitem = int(re.search('[0-9]+',blkstr4.group()).group())
        return nitem
    return nitem

# %%
# セット書籍の冊数を取り出す
df1 = df1.assign(n_bulk = df1['title'].apply(func_bulk))
df81 = df1[df1['n_bulk'] > 0]
df81.head(2)
# Out:
#                                              title  ... n_bulk
# 19                                  アシガール 1-14巻セット  ...     14
# 36  100年ドラえもん　50周年メモリアルエディション 『ドラえもん』全45巻・豪華愛蔵版セット  ...     45
#
# [2 rows x 13 columns]

# %% [markdown]
# **データフレーム内の複数の列の演算により新たな列を作成する。**

# %% [markdown]
# これまでにもデータフレーム内のある一つの列から、ある演算によって新しい列を作り出す例が出てきました。演算が簡単なものならばその列を作り出す文の中に式を埋め込めばいいのですが、式が複雑な場合は別途関数を定義して、元の列に関してapplyメソッドを使う、という形でした。それでは、データフレーム内の複数の列を使って新しい列を作り出す場合はどうするのでしょうか。その場合は、データフレームそのものについてappyメソッドを適用します。

# %%
# データフレーム内の複数の列の演算により新しい列を作成する
def func_review_pi(df):
  return np.log(df.loc['reviewCount']+1) + df.loc['reviewAverage']
df51 = df1.assign(review_pi = df1.apply(func_review_pi, axis=1))
df51.head(2)
# Out:
#                  title subTitle seriesName  ... reviewAverage n_bulk review_pi
# 0       ダンススクエア vol.39                      ...          0.00      0  0.000000
# 1  鬼滅の刃 23巻 フィギュア付き同梱版           ジャンプコミックス  ...          4.41      0  7.588054
#
# [2 rows x 14 columns]

# %% [markdown]
# **新しい列を作成するための関数に他の引数がある場合**

# %% [markdown]
# これまでの例では、データフレーム内の新たな列を作るための関数には「元の列」や「元のデータフレーム」以外の引数はありませんでした。今度は、その関数が別途他の引数を必要とする場合の記述を見てみます。
# ここでの例は、書籍のタイトルにある指定したキーワードが含まれていたら、あるジャンルの書籍であると判定するための関数の作成です。一つのジャンルについてキーワードは複数あるものとし、キーワードは2次元のリストで与えられるとします。

# %%
# ジャンル別のキーワードのリスト
# 0:経済, 1:歴史, 2:科学, 3:医学, 4:旅行, 5:辞典, 6:人生, 7:食事, 8:情報, 9:入試, 10:漫画
kws = [['経済','財務','お金','家計','会計','金融'],
       ['史','古代'],
       ['科学','サイエンス','宇宙'],
       ['医','癌','内科','外科','歯科','手術','疾患'],
       ['旅','紀行'],
       ['辞典','広辞苑'],
       ['人生','生き方','生きかた','ライフ'],
       ['料理','食事','グルメ','レシピ'],
       ['Excel','Word','Python','iPhone','iPad','プログラミング','アプリ','HTML','ソフトウェア','情報技術','Adobe'],
       ['入試','中学受験','高校受験','大学受験'],
       ['鬼滅の刃','リベンジャーズ','るろうに剣心','スライムだった件','青の祓魔師','呪術廻戦','進撃の巨人']]

# %%
def func_genre(s, ww, k):
  """文字列sに2次元リストwwの第kジャンルのキーワードが
  含まれていれば1, 含まれていなければ0を返す"""
  q = 0
  for j in range(len(ww[k])):
    if ww[k][j] in s:
      q = 1
  return q

# %% [markdown]
# 演算の元になる列以外の引数がある場合、その引数はapply()メソッドの中で引数名=値の形で指定します。

# %%
# 各キーワードを含むかどうかのダミー変数を作成する
df1= df1.assign(G経済=df1['title'].apply(func_genre, ww=kws, k=0))
df1= df1.assign(G歴史=df1['title'].apply(func_genre, ww=kws, k=1))
df1= df1.assign(G科学=df1['title'].apply(func_genre, ww=kws, k=2))
df1= df1.assign(G医学=df1['title'].apply(func_genre, ww=kws, k=3))
df1= df1.assign(G旅行=df1['title'].apply(func_genre, ww=kws, k=4))
df1= df1.assign(G辞典=df1['title'].apply(func_genre, ww=kws, k=5))
df1= df1.assign(G人生=df1['title'].apply(func_genre, ww=kws, k=6))
df1= df1.assign(G食事=df1['title'].apply(func_genre, ww=kws, k=7))
df1= df1.assign(G情報=df1['title'].apply(func_genre, ww=kws, k=8))
df1= df1.assign(G入試=df1['title'].apply(func_genre, ww=kws, k=9))
df1= df1.assign(G漫画=df1['title'].apply(func_genre, ww=kws, k=10))

# %% [markdown]
# 実際に各ジャンルに該当する書籍が何件あったかを見るには、数値変数に絞り込んで合計を計算します。

# %%
# 文字列変数を除外する
df41 = df1.select_dtypes(exclude='object')
# 数値変数の合計をみる
df42 = df41.sum()
df42
# Out:
# itemPrice        5708324.00
# reviewCount        16681.00
# reviewAverage       4738.91
# n_bulk               305.00
# G経済                   52.00
# G歴史                   46.00
# G科学                   24.00
# G医学                   62.00
# G旅行                   20.00
# G辞典                   29.00
# G人生                   44.00
# G食事                   45.00
# G情報                   19.00
# G入試                   30.00
# G漫画                   41.00
# dtype: float64

# %%
# アイテム価格の回帰分析
import statsmodels.formula.api as smf
expr = 'itemPrice ~ reviewCount+reviewAverage+n_bulk+G経済+G歴史+G科学+G医学+G旅行+G辞典+G人生+G食事+G情報+G入試+G漫画'
results = smf.ols(expr, data=df41).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              itemPrice   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     53.23
# Date:                Fri, 23 Jul 2021   Prob (F-statistic):          3.54e-133
# Time:                        00:25:30   Log-Likelihood:                -28364.
# No. Observations:                3000   AIC:                         5.676e+04
# Df Residuals:                    2985   BIC:                         5.685e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1775.2010     73.002     24.317      0.000    1632.061    1918.341
# reviewCount      -1.2299      1.986     -0.619      0.536      -5.124       2.664
# reviewAverage   -19.8074     27.253     -0.727      0.467     -73.243      33.628
# n_bulk         1032.4947     40.512     25.486      0.000     953.061    1111.929
# G経済             301.3290    434.301      0.694      0.488    -550.230    1152.888
# G歴史            -662.6406    473.987     -1.398      0.162   -1592.014     266.733
# G科学            4638.4442    635.911      7.294      0.000    3391.576    5885.313
# G医学            1461.0959    398.366      3.668      0.000     679.997    2242.195
# G旅行            -157.6909    696.848     -0.226      0.821   -1524.043    1208.661
# G辞典            1038.5332    583.676      1.779      0.075    -105.915    2182.982
# G人生            -445.0855    471.660     -0.944      0.345   -1369.897     479.726
# G食事            -468.3314    466.292     -1.004      0.315   -1382.618     445.956
# G情報             617.2984    713.324      0.865      0.387    -781.358    2015.955
# G入試             818.3626    569.991      1.436      0.151    -299.253    1935.978
# G漫画            -670.5109    490.413     -1.367      0.172   -1632.092     291.070
# ==============================================================================
# Omnibus:                     5883.346   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15518915.762
# Skew:                          15.276   Prob(JB):                         0.00
# Kurtosis:                     354.024   Cond. No.                         378.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# レビュー得点の回帰分析
import statsmodels.formula.api as smf
expr = 'reviewAverage ~ G経済+G歴史+G科学+G医学+G旅行+G辞典+G人生+G食事+G情報+G入試+G漫画'
results = smf.ols(expr, data=df41).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          reviewAverage   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     9.117
# Date:                Fri, 23 Jul 2021   Prob (F-statistic):           3.11e-16
# Time:                        00:25:30   Log-Likelihood:                -6531.6
# No. Observations:                3000   AIC:                         1.309e+04
# Df Residuals:                    2988   BIC:                         1.316e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.5380      0.042     36.817      0.000       1.456       1.620
# G経済            0.3149      0.300      1.050      0.294      -0.273       0.903
# G歴史            0.2021      0.319      0.634      0.526      -0.423       0.827
# G科学           -0.5040      0.439     -1.148      0.251      -1.365       0.357
# G医学           -0.4643      0.275     -1.689      0.091      -1.003       0.075
# G旅行           -0.6682      0.481     -1.389      0.165      -1.611       0.275
# G辞典            2.9489      0.399      7.384      0.000       2.166       3.732
# G人生            0.0799      0.326      0.245      0.806      -0.559       0.718
# G食事            0.8321      0.322      2.587      0.010       0.201       1.463
# G情報            0.4689      0.492      0.952      0.341      -0.497       1.434
# G入試           -1.3780      0.393     -3.509      0.000      -2.148      -0.608
# G漫画            1.4515      0.337      4.312      0.000       0.791       2.112
# ==============================================================================
# Omnibus:                    60732.669   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              472.847
# Skew:                           0.695   Prob(JB):                    2.10e-103
# Kurtosis:                       1.640   Cond. No.                         12.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

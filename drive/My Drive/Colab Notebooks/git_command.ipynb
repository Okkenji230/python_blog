# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git config --global user.email "nicjps@gmail.com"
# !git config --global user.name "Okkenji230"
# !echo "# python_blog" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/Okkenji230/python_blog.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# [master (root-commit) a379339] first commit
#  1 file changed, 2 insertions(+)
#  create mode 100644 README.md
# fatal: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git add '/content/drive/My Drive/Colab Notebooks/git_command.ipynb'
# !git commit -m "Add files 07Mar22a"
# !git remote set-url origin https://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@github.com/Okkenji230/python_blog.git
# !git push origin main
# Out:
# [main 4987288] Add files 07Mar22a
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Support for password authentication was removed on August 13, 2021. Please use a personal access token instead.
# remote: Please see https://github.blog/2020-12-15-token-authentication-requirements-for-git-operations/ for more information.
# fatal: Authentication failed for 'https://Okkenji230:ym12tn40@github.com/Okkenji230/python_blog.git/'
